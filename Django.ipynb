# %% [markdown]
# # Dejango
# ![django.png](attachment:a272add3-d9fb-4a2b-a119-19e1eb5339df.png)

# %% [markdown]
# #
# dir Diagonal 12 #28-22 Altos del San Juan
#
# ### Nombre del projecto first-project
#
# ## hosname: hostkaliman
# ### mi contrasea = laila2perraHermosa
# 1. Despues de tener una cuenta, seleccionamos el servicio en mi caso es una aplicacion web django
# 2. Debemos ver esta pantalla
# ![digitaloccean1.png](attachment:b31e268c-b6d4-44c6-ae69-b11a97292329.png)
#
# ### password para acceder a la maquina virtual yeveja1102@
# ## El boton create me permite crear el servidor virtual donde voy a desplegar mi proyecto [draple]
#
# ## Ahora tenemos una ip: 198.199.75.60 con dominio hostkaliman
#
# Como acceder al servidor ?
# - abrir el cmd en administrador
# - >ssh root@ 198.199.75.60
#   >pasword: laila2perraHermosa
# # Ya podemos iniciar el proceso deactualizar pendientes, instalar herramientas como python, django o Nginx
#
# Si todo va bien debemos estar en la ruta del servidor
# ## root@hostkaliman:~#
# 1.0 root@hostkaliman:~# sudo apt update (nos actualizamos todas las aplicaciones)
# 2.0 sudo apt upgrade
#
# Si todo transcurre normalmente ya tenemos configurado el Sistema operativo y ubuntu
#
# Lo que sigue es configurar el servidor para que pueda servir nuestra aplicación

# %% [markdown]
# # Instalación del VPS
# # Correo electrónico ingeniero.sistem123@gmail.com password: yeveja1102@
# # DigitalOcean
# # Miembro a DigitalOcean
#
# # ingeniero.sistem123@gmail.com (6/1/2925)
# # Cuenta https://cloud.digitalocean.com/account/billing?i=e4a59d

# %% [markdown]
# 1. abrimos powershell
# 2. ejecutamos ssh root@198.199.75.60
# 3. ingresamos la contraseña laila2perraHermosa
# 4. sale root@hostkaliman~#     esto indica que hemos ingresado al servidor
# Ahora vamos a crear la estructura de carpetas para mi proyecto
# # - mkdir /webapps       (Aqui almacenamos todas nuestras aplicaciones)
# - cd /
# - ls  muestra la estructura de carpetas en nuestro root
# - cd webapps
# - root@hostkaliman~# :/weapps# sudo apt install git (instalamos el git , aclaremos que no es necesario usar el sudo por que estamos como superusuario)
#
# Ahora vamos a clonar nuestro proyecto que tenemos en github
# # root@hostkaliman~# :/weapps# git clone https:/github.com/hombremono873/empleado.git
#
# Por defecto linux trae instalado python3 (por lo que no es requerido instalar nada de python)
# ## Creamos el entorno virtual
#  root@hostkaliman~# :/weapps#apt install python3.12-venv
#  root@hostkaliman~# :/weapps#python3 -m venv empleados
#  ahora tenemos dos entornos en la carpeta de nuestro proyecto debemos eliminar la de empleado y dejar la de empleados la ultima que hemos creado
#
#   root@hostkaliman~# rm -r empleado (empleado se trajo durante la clonacion del proyecto)
#
#  ingresamos a  root@hostkaliman~#cd empleados    (al entorno que hemos creado)
#
#  podemos ver toda la estructura
#  . bin
#  . include
#  . lib
#  . lib64
#  . pyenv.cfg
#  vamos a clonar nuestro proyecto
# root@hostkaliman:/weapps/empleados~# git clone https:/github.com/hombremono873/empleado.git
#
# ahora tenemos todo la estructura completa mas el poyecto empleado
#
# debemos activar el entorno
# ### root@hostkaliman:/weapps/empleados~#source bin/activate
# (empleados)  root@hostkaliman:/weapps/empleados~#
#
# instalamos django
# (empleados)  root@hostkaliman:/weapps/empleados~#pip install django
#
# (empleados)  root@hostkaliman:/weapps/empleados~#sudo apt install postgresql postgresql-contrib
#
# Para que funcione bien postgresql debemos tambien instalar :
# (empleados)  root@hostkaliman:/weapps/empleados~# pip install psycopg2-binary
#
# Crear la base de datos
# (empleados)  root@hostkaliman:/weapps/empleados~#su postgres
#
# sale postgres@hostkaliman:/webapps/empleados$createdb dbempleado
#
# Crear el usuario por defecto durante la implementacion hemos usado
# $ createuser postgres
#
# entarndo a la base de datos
#
# ..$psql dbempleado
# dbempleado=# alter user postgres with password 'Root123';     (Cambiar el usuario)
# AAALTER ROLE
# dbempleado=#
#
# salir de la consola postgre
# dbempleado# \q
# salir de postgres
# -------$exit
#
# Si ejecutamos el proyecto
# python manage.py runserver
# nos sale problemas de migraciones pendientes que es necesario hacer para que el proyecto este sincronizado
# hacemos las migraciones
#
# Ahora es necesario que cuando escribamos la ip que nos asignaron (198.199.75.60) en el navegador se ejecute nuestra aplicacion
#
# para esto es necesario instalar otra herramienta y es Nginx
# ls /webapps/empleados/empleados

# %% [markdown]
# # Modelos avanzados PostGresSQL
# ![posgres.png](attachment:eb9eeb1c-29d5-4321-a3c3-5b7fd937bb77.png)

# %% [markdown]
# ![bdd_biblioteca.png](attachment:f5cba9e5-9ba8-4876-bc43-e7cba34abe49.png)

# %% [markdown]
# # Creacion Proyecto Libro
# 1. Crear entorno virtual
# 2. crear neun/biblioteca/env "Creamos el entorno virtrual dentro de la carpeta biblioteca
# 3. Abrimos la consola en el directorio ven.
# 4. Si no ha instalado virtualenv si no está instalado (pip install virtualenv)
# 5. Crear el entorno virtual para el nuevo proyecto
#
# ##   c:\neun\biblioteca> python -m venv libro
#    (Nuestro entorno virtual se llama libro)
#    Despues de crear un entorno virtual veremos la siguiente estructura
#
# 6. # ![entorno.png](attachment:e8443cbf-e10b-4949-a1d8-cbee6cc0a3d3.png)
# 7. Activamos el entorno virtual asi:
# ##   c:\neun\biblioteca\libro\Scripts>activate
#
# 8. Debemos instalar dejango con el entorno activado
# ## (libro) c:\neun\biblioteca> pip install django
#
# 9. Ahora que tenemos el entorno libro y hemos instalado dejango debemos crear el proyecto
# 10. (libro) c:\neun\biblioteca>django-admin startproject biblioteca
# 11. Ahora en la carpeta biblioteca tenemos un entorno virtual llamado libro y el proyecto llamado biblioteca
# 12.
# 13.
